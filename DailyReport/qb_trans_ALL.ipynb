# %%
import pandas as pd
import numpy as np
import datetime
import calendar

# %%
folderName = 'C:\\Users\\ms\\Desktop\\qb_trans_ALL\\'
fileName = folderName + 'qb_trans_ALL.xlsx'
data = pd.read_excel(fileName,sheet_name='Sheet1')
# Out:
#                    用户uid              交易订单ID                交易时间  状态 交易类型  \
# 0      27695471130591232  138738973545627650 2018-07-05 11:52:18  成功   年费
# 1      27695471130591232  138740892322005096 2018-07-05 12:22:04  成功   消费
# 2      27695471130591232  138928435292045413 2018-07-07 12:53:06  成功   消费
# 3      27735476603469824  138738875835908208 2018-07-05 11:50:47  成功   年费
# 4      27735476603469824  139017238034284556 2018-07-08 11:51:30  成功   消费
# 5      27735476603469824  139051294979293199 2018-07-08 20:40:09  成功   消费
# 6      28057837660028928  138738973547462665 2018-07-05 11:52:18  成功   年费
# 7      29396022629253120  138755418975141990 2018-07-05 16:07:34  成功   年费
# 8      31425365824258048  138739037971972205 2018-07-05 11:53:18  成功   年费
# 9      31425365824258048  138740017224515694 2018-07-05 12:08:30  成功   提现
# 10     32538734617444352  138742590982356993 2018-07-05 12:48:27  成功   年费
# 11     32718745301958656  137528177145970826 2018-06-22 10:38:16  成功   年费
# 12     32718745301958656  137530229060042755 2018-06-22 11:10:07  成功   提现
# 13     32718745301958656  137532147848478847 2018-06-22 11:39:53  成功   消费
# 14     32718745301958656  137623939876945945 2018-06-23 11:24:41  成功   消费
# 15     32718745301958656  137714771998834701 2018-06-24 10:54:34  成功   消费
# 16     32718745301958656  137716241951391855 2018-06-24 11:17:23  成功   消费
# 17     32718745301958656  137908495419736068 2018-06-26 13:01:34  成功   消费
# 18     32718745301958656  138087089828823150 2018-06-28 11:13:42  成功   消费
# 19     32718745301958656  138093187609690119 2018-06-28 12:48:22  成功   消费
# 20     32718745301958656  138122296743985266 2018-06-28 20:20:12  成功   消费
# 21     32718745301958656  138186191928066156 2018-06-29 12:51:59  成功   消费
# 22     32718745301958656  138204210389352550 2018-06-29 17:31:39  成功   消费
# 23     32718745301958656  138213337195905127 2018-06-29 19:53:20  成功   消费
# 24     32718745301958656  138258801570906115 2018-06-30 07:39:02  成功   消费
# 25     32718745301958656  138262381427720302 2018-06-30 08:34:35  成功   消费
# 26     32718745301958656  138266518552871024 2018-06-30 09:38:49  成功   消费
# 27     32718745301958656  138489102011498601 2018-07-02 19:13:46  成功   消费
# 28     32718745301958656  138766172500295696 2018-07-05 18:54:28  成功   消费
# 29     32718745301958656  138835550181032038 2018-07-06 12:51:21  成功   消费
# ..                   ...                 ...                 ...  ..  ...
# 728   138744983278600303  139227009607041042 2018-07-10 18:07:33  成功   消费
# 729   138744983278600303  139227034303627378 2018-07-10 18:07:53  成功   消费
# 730   138744983278600303  139227066515095593 2018-07-10 18:08:26  成功   消费
# 731   138744983278600303  139227095504552040 2018-07-10 18:08:51  成功   消费
# 732   138744983278600303  139227141677023241 2018-07-10 18:09:35  成功   消费
# 733   138744983278600303  139227168521355276 2018-07-10 18:10:00  失败   消费
# 734   138744983278600303  139227185699389553 2018-07-10 18:10:15  失败   消费
# 735   138744983278600303  139227205027790956 2018-07-10 18:10:34  失败   消费
# 736   138744983278600303  139227234017509521 2018-07-10 18:11:01  成功   消费
# 737   138744983278600303  139404403566477312 2018-07-12 16:01:03  成功   消费
# 738   138744983278600303  139404429336543252 2018-07-12 16:01:28  成功   消费
# 739   138744983278600303  139404457254617092 2018-07-12 16:01:53  成功   消费
# 740   138744983278600303  139404477656236140 2018-07-12 16:02:13  成功   消费
# 741   138744983278600303  139404498056019983 2018-07-12 16:02:30  成功   消费
# 742   138744983278600303  139404515235102837 2018-07-12 16:02:48  成功   消费
# 743   138759928669552744  138760477372612618 2018-07-05 17:26:05  成功   年费
# 744   138759928669552744  139145490053496934 2018-07-09 21:02:14  成功   消费
# 745   138759928669552744  139687521368965121 2018-07-15 17:15:37  成功   消费
# 746   139495905653964900  139496385659830297 2018-07-13 15:48:53  成功   年费
# 747   139495905653964900  139496555312349188 2018-07-13 15:51:31  成功   提现
# 748   139495905653964900  139855939922067459 2018-07-17 12:49:53  成功   消费
# 749   139761816749490280  139763353312329731 2018-07-16 12:52:46  成功   年费
# 750   139761816749490280  139769561687293966 2018-07-16 14:29:08  成功   提现
# 751   352355329861682176  138738940260679707 2018-07-05 11:51:47  成功   年费
# 752   374137243750695936  138741912377786385 2018-07-05 12:37:55  成功   年费
# 753   385289789001843712  138743332939006064 2018-07-05 12:59:58  成功   年费
# 754   427088764255683584  137993819244757115 2018-06-27 11:05:59  成功   年费
# 755   700638759989101568  139380038216482828 2018-07-12 09:42:56  成功   年费
# 756  6221140056443469824  138894933473394699 2018-07-07 04:13:07  成功   年费
# 757  6221140056443469824  138928914179063809 2018-07-07 13:00:32  成功   消费
#
#         交易金额              商户名称  付款银行 卡种类 支付渠道  期数  \
# 0       1.00                年费  上海银行  赢卡  NaN   1
# 1       7.00  深圳市顶全便利店有限公司（全家）  上海银行  赢卡   QR   1
# 2      32.00     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 3       1.00                年费  上海银行  赢卡  NaN   1
# 4      20.38     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 5      22.90     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 6       1.00                年费  上海银行  赢卡  NaN   1
# 7       1.00                年费  上海银行  赢卡  NaN   1
# 8       1.00                年费  上海银行  赢卡  NaN   1
# 9     100.00                借款  上海银行  赢卡  NaN   3
# 10      1.00                年费  上海银行  赢卡  NaN   1
# 11      1.00                年费  上海银行  赢卡  NaN   1
# 12    150.00                借款  上海银行  赢卡  NaN   3
# 13     24.40     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 14     28.30     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 15     59.30     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 16     21.30     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 17     29.80   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 18      4.30        上海罗森便利有限公司  上海银行  赢卡   QR   1
# 19     14.90     上海福满家便利有限公司全家  上海银行  赢卡   AM   1
# 20     17.80   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 21     29.80   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 22     30.30     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
# 23      9.90     上海福满家便利有限公司全家  上海银行  赢卡   AM   1
# 24      2.00   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 25     14.80   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 26     25.00   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 27      5.80       上海茱莉亚食品有限公司  上海银行  赢卡   QR   1
# 28      7.20   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# 29     34.80   上海福满家便利有限公司（全家）  上海银行  赢卡   QR   1
# ..       ...               ...   ...  ..  ...  ..
# 728  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 729  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 730  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 731  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 732  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 733  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 734  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 735  1000.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 736   999.00       滨州市滨城区美静美容院  上海银行  赢卡   QR   1
# 737  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 738  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 739  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 740  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 741  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 742  1000.00          北京徐月玲茶叶店  上海银行  赢卡   QR   1
# 743     1.00                年费  上海银行  赢卡  NaN   1
# 744  3999.00       北京市馨蕊腾飞建材批发  上海银行  赢卡   AM   1
# 745  1999.00     北京市西土瓦森组装沙发批发  上海银行  赢卡   AM   1
# 746     1.00                年费  上海银行  赢卡  NaN   1
# 747   200.00                借款  上海银行  赢卡  NaN  12
# 748     8.00      上海食旸餐饮管理有限公司  上海银行  赢卡   QR   1
# 749     1.00                年费  上海银行  赢卡  NaN   1
# 750   200.00                借款  上海银行  赢卡  NaN   3
# 751     1.00                年费  上海银行  赢卡  NaN   1
# 752     1.00                年费  上海银行  赢卡  NaN   1
# 753     1.00                年费  上海银行  赢卡  NaN   1
# 754     1.00                年费  上海银行  赢卡  NaN   1
# 755     1.00                年费  上海银行  赢卡  NaN   1
# 756     1.00                年费  上海银行  赢卡  NaN   1
# 757   133.50     美团点评（商城）（云闪付）  上海银行  赢卡   AM   1
#
#                                 备注 Unnamed: 12
# 0                              NaN      首次交易人数
# 1                              NaN           1
# 2                              NaN          11
# 3                              NaN         NaN
# 4                              NaN      首次交易人数
# 5                              NaN         NaN
# 6                              NaN           6
# 7                              NaN         NaN
# 8                              NaN         NaN
# 9                  {"purpose":"2"}         NaN
# 10                             NaN         NaN
# 11                             NaN         NaN
# 12                 {"purpose":"4"}         NaN
# 13                             NaN         NaN
# 14                             NaN         NaN
# 15                             NaN         NaN
# 16                             NaN         NaN
# 17                             NaN         NaN
# 18                             NaN         NaN
# 19                             NaN         NaN
# 20                             NaN         NaN
# 21                             NaN         NaN
# 22                             NaN         NaN
# 23                             NaN         NaN
# 24                             NaN         NaN
# 25                             NaN         NaN
# 26                             NaN         NaN
# 27                             NaN         NaN
# 28                             NaN         NaN
# 29                             NaN         NaN
# ..                             ...         ...
# 728                            NaN         NaN
# 729                            NaN         NaN
# 730                            NaN         NaN
# 731                            NaN         NaN
# 732                            NaN         NaN
# 733  {"reason":"额度扣减失败:超过消费限制额度!"}         NaN
# 734  {"reason":"额度扣减失败:超过消费限制额度!"}         NaN
# 735  {"reason":"额度扣减失败:超过消费限制额度!"}         NaN
# 736                            NaN         NaN
# 737                            NaN         NaN
# 738                            NaN         NaN
# 739                            NaN         NaN
# 740                            NaN         NaN
# 741                            NaN         NaN
# 742                            NaN         NaN
# 743                            NaN         NaN
# 744                            NaN         NaN
# 745                            NaN         NaN
# 746                            NaN         NaN
# 747                {"purpose":"4"}         NaN
# 748                            NaN         NaN
# 749                            NaN         NaN
# 750                {"purpose":"4"}         NaN
# 751                            NaN         NaN
# 752                            NaN         NaN
# 753                            NaN         NaN
# 754                            NaN         NaN
# 755                            NaN         NaN
# 756                            NaN         NaN
# 757                            NaN         NaN
#
# [758 rows x 13 columns]

# %%
data.shape
# Out:
# (758, 13)

# %%
# 筛选支付状态为成功的数据
data = data[data['状态'] == '成功']

# %% [markdown]
# ### 自动获取日期

# %%
# 今天的日期
today = datetime.date.today()

# 昨天的日期
yesterday = (datetime.date.today() + datetime.timedelta(days=-1)).strftime('%Y-%m-%d')
yesterday = datetime.datetime.strptime(yesterday, "%Y-%m-%d")
yesterday = yesterday.date()

# %%
# 获取上周日日期
def getLastSunday():

    today = datetime.date.today()

    oneday = datetime.timedelta(days = -1)

    m1 = calendar.SUNDAY

    while today.weekday() != m1:
        today += oneday

    lastSunday = today.strftime('%Y-%m-%d')

    return datetime.datetime.strptime(lastSunday, "%Y-%m-%d").date()


# 获取上周一日期
def getLastMonday():

    lastSunday = getLastSunday()

    oneday = datetime.timedelta(days = -1)

    m1 = calendar.MONDAY

    while lastSunday.weekday() != m1:
        lastSunday += oneday

    lastMonday = lastSunday.strftime('%Y-%m-%d')

    return datetime.datetime.strptime(lastMonday, "%Y-%m-%d").date()

# %%
import xlwings as xw

# %%
reportName = 'C:\\Users\\ms\\Desktop\\qb_trans_ALL\\dailyReport.xlsx'
wb1 = xw.Book(reportName)
detail_sheet1 = xw.Sheet("Sheet1")


detail_sheet1.range('H2').options(transpose=True).value='消费'
detail_sheet1.range('J2').options(transpose=True).value='交易笔数'
detail_sheet1.range('K2').options(transpose=True).value='交易金额'
detail_sheet1.range('L2').options(transpose=True).value='交易人数'
detail_sheet1.range('M2').options(transpose=True).value='首次交易人数'

detail_sheet1.range('H6').options(transpose=True).value='提现'
detail_sheet1.range('J6').options(transpose=True).value='交易笔数'
detail_sheet1.range('K6').options(transpose=True).value='交易金额'
detail_sheet1.range('L6').options(transpose=True).value='交易人数'
detail_sheet1.range('M6').options(transpose=True).value='首次交易人数'

# %% [markdown]
# ### 统计昨天信息

# %%
# 昨天统计
yesterdayData = data[data['交易时间'].apply(lambda x : x.month == yesterday.month  and x.day == yesterday.day )]
# 获取昨天之前的数据
yesBefor = data[data['交易时间'].apply(lambda x : (x.month == 7 and x.day < yesterday.day) or (x.month < yesterday.month )  )]

for subData in yesBefor.groupby('交易类型'):
    if subData[0] == '消费':
        yesBeforUconsume = list(set(subData[1]['用户uid']))
    elif subData[0] == '提现':
        yesBeforUdraw = list(set(subData[1]['用户uid']))
        

for subData in yesterdayData.groupby('交易类型'):
    if subData[0] == '消费':
        yes_consume = {}
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
       
        
        for i in set(subData[1]['用户uid']):
            if i not in yesBeforUconsume:
                newUser.append(i)
        
        detail_sheet1.range('I3').options(transpose=True).value='昨日:'+str(yesterday)
        detail_sheet1.range('J3').options(transpose=True).value=tradeTotal
        detail_sheet1.range('K3').options(transpose=True).value=tradeAmount
        detail_sheet1.range('L3').options(transpose=True).value= tradeNum
        detail_sheet1.range('M3').options(transpose=True).value= len(newUser)
        wb1.save()
        
    if subData[0] == '提现':
        
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
       
        
        for i in set(subData[1]['用户uid']):
            if i not in yesBeforUdraw:
                newUser.append(i)
        
        
        detail_sheet1.range('I7').options(transpose=True).value='昨日:'+str(yesterday)
        detail_sheet1.range('J7').options(transpose=True).value = tradeTotal
        detail_sheet1.range('K7').options(transpose=True).value = tradeAmount
        detail_sheet1.range('L7').options(transpose=True).value = tradeNum
        detail_sheet1.range('M7').options(transpose=True).value = len(newUser)
        wb1.save()

# %% [markdown]
# ### 上周的数据

# %%
lastWeekData  = data[data['交易时间'].apply(lambda x : (x.month == getLastSunday().month  and x.day <= getLastSunday().day) 
                                        and ( x.month == getLastMonday().month and x.day >= getLastMonday().day  ))]
# 获取上周之前的数据
lastWeekBefor = data[data['交易时间'].apply(lambda x : (x.month == getLastMonday().month and x.day < getLastMonday().day) 
                                        or (x.month < getLastMonday().month )  )]

for subData in lastWeekBefor.groupby('交易类型'):
    if subData[0] == '消费':
        lastWeekBeforUconsume = list(set(subData[1]['用户uid']))
    elif subData[0] == '提现':
        lastWeekBeforUdraw = list(set(subData[1]['用户uid']))


for subData in lastWeekData.groupby('交易类型'):
    if subData[0] == '消费':
        yes_consume = {}
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
       
        
        for i in set(subData[1]['用户uid']):
            if i not in lastWeekBeforUconsume:
                newUser.append(i)
        
        detail_sheet1.range('I4').options(transpose=True).value='上周:'+str(getLastMonday())+'~'+str(getLastSunday())
        detail_sheet1.range('J4').options(transpose=True).value=tradeTotal
        detail_sheet1.range('K4').options(transpose=True).value=tradeAmount
        detail_sheet1.range('L4').options(transpose=True).value= tradeNum
        detail_sheet1.range('M4').options(transpose=True).value= len(newUser)
        wb1.save()
        
    if subData[0] == '提现':
        yes_drawing = {}
        
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
       
        
        for i in set(subData[1]['用户uid']):
            if i not in lastWeekBeforUdraw:
                newUser.append(i)
        
        detail_sheet1.range('I8').options(transpose=True).value='上周:'+str(getLastMonday())+'~'+str(getLastSunday())
        detail_sheet1.range('J8').options(transpose=True).value = tradeTotal
        detail_sheet1.range('K8').options(transpose=True).value = tradeAmount
        detail_sheet1.range('L8').options(transpose=True).value = tradeNum
        detail_sheet1.range('M8').options(transpose=True).value = len(newUser)
        wb1.save()

# %% [markdown]
# ### 历史数据

# %%
historyData  = data[~data['交易时间'].apply(lambda x : x.month == today.month  and x.day == today.day  )]

for subData in historyData.groupby('交易类型'):
    if subData[0] == '消费':
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
    
        detail_sheet1.range('I5').options(transpose=True).value='历史信息<'+str(today)
        detail_sheet1.range('J5').options(transpose=True).value=tradeTotal
        detail_sheet1.range('K5').options(transpose=True).value=tradeAmount
        detail_sheet1.range('L5').options(transpose=True).value= tradeNum
        wb1.save()
        
    if subData[0] == '提现':       
        newUser = []
        
        tradeTotal = len(subData[1]['交易订单ID']) # 交易笔数
        tradeNum = len(set(subData[1]['用户uid']))   # 人数
        tradeAmount = subData[1]['交易金额'].sum() # 交易金额
       
        detail_sheet1.range('I9').options(transpose=True).value='历史信息<'+str(today)
        detail_sheet1.range('J9').options(transpose=True).value = tradeTotal
        detail_sheet1.range('K9').options(transpose=True).value = tradeAmount
        detail_sheet1.range('L9').options(transpose=True).value = tradeNum

        wb1.save()

# %% [markdown]
# ### 绘图

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']  # 指定默认字体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像时负号'-'显示为方块的问题

#mpl.rcParams['font.family'] = 'sans-serif'
#mpl.rcParams['font.sans-serif'] = 'NSimSun,Times New Roman' # 中文除外的设置成New Roman，中文设置成宋体

# %%
data['交易时间'] = data['交易时间'].apply( lambda x: datetime.datetime.strptime(x.strftime("%Y-%m-%d") ,"%Y-%m-%d"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for subData in data.groupby('交易类型'):
    # 消费数据集
    if subData[0] == '消费':
        
        consumeData = subData[1]
    # 提现数据集
    if subData[0] == '提现':
        drawData = subData[1]

# %%
dateTime= []
consumeCount = [] # 消费人数
consumeTotal = [] # 消费笔数
consumeRate = [] # 消费均额
# 消费
for i,j in consumeData.groupby('交易时间'):
    dateTime.append(i)
    consumeCount.append(len(set(j['用户uid'])))
    consumeTotal.append(len(j['交易订单ID']))
    consumeRate.append(sum(j['交易金额']/len(j['交易订单ID'])))

# %%
# 绘制消费数据

fig = plt.figure(figsize=(10,9)) 
ax1 = fig.add_subplot(211)
# mec 边界颜色；mfc 填充颜色；
plt.plot(dateTime, consumeCount, marker='o', mec='r', mfc='w',label='消费人数') 
plt.plot(dateTime, consumeTotal, marker='*', ms=10,label= '消费笔数')

plt.legend(loc='upper left')  # 让图例生效
plt.margins(0) # 收缩空白
plt.subplots_adjust(bottom=0.15)

# plt.xlabel("日 期",fontsize=10) #X轴标签
fig.autofmt_xdate(rotation = 30) # x轴标签倾斜30度


plt.ylabel("数 量",fontsize=15) #Y轴标签
plt.ylim((0, 40))  # 范围 
plt.yticks(np.arange(0, 40, 2)) # 刻度
plt.title("统计消费数据",fontsize=18,color='r') #标题

# 绘制笔均
fig = plt.figure(figsize=(10,9)) 
ax2 = fig.add_subplot(212)

plt.plot(dateTime,consumeRate,marker='+', mec='k', mfc='w',label = '消费笔均')
plt.legend(loc='upper left') 
plt.subplots_adjust(bottom=0.15)

plt.xlabel("日 期",fontsize=15) #X轴标签
plt.ylabel("平均每笔消费",fontsize=15) #Y轴标签
fig.autofmt_xdate(rotation = 30)


plt.show()

# %%
# 提现

drawDateTime= []
drawCount = [] # 提现人数
drawTotal = [] # 提现笔数
drawRate = []

for i,j in drawData.groupby('交易时间'):
    drawDateTime.append(i)
    drawCount.append(len(set(j['用户uid'])))
    drawTotal.append(len(j['交易订单ID']))
    drawRate.append(sum(j['交易金额']/len(j['交易订单ID'])))

# %%
fig = plt.figure(figsize=(10,9)) 
ax1 = fig.add_subplot(211) 


plt.plot(drawDateTime, drawCount, marker='o', mec='r', mfc='w',label='提现人数')
plt.plot(drawDateTime, drawTotal, marker='*', ms=10,label= '提现笔数')


plt.legend(loc='upper left')  # 让图例生效
plt.margins(0)
plt.subplots_adjust(bottom=0.15)
#plt.xlabel("日 期",fontsize=10) #X轴标签
plt.ylabel("数 量",fontsize=15) #Y轴标签
plt.ylim((0, 18))
plt.yticks(np.arange(0, 18, 1))
plt.title("统计提现数据",fontsize=18,color='r') #标题
fig.autofmt_xdate(rotation = 30)



fig = plt.figure(figsize=(10,9))
ax2 = fig.add_subplot(212)

plt.plot(drawDateTime,drawRate,marker='+', mec='k', mfc='w',label = '提现笔均')
plt.legend(loc='upper left')
plt.subplots_adjust(bottom=0.15)

plt.xlabel("日 期",fontsize=15) #X轴标签
#plt.xticks(np.array(drawDateTime))
plt.ylabel("平均每笔提现",fontsize=15) #Y轴标签
fig.autofmt_xdate(rotation = 30)

plt.show()
